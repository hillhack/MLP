# %%
import pandas as pd
df = pd.read_csv("train.csv")
print(df.shape)
df.head()
# Out:
# (100000, 76)
#                           MachineID   ProductName EngineVersion  \
# 0  f541bae429089117c4aac39c90dd3416  win8defender   1.1.15200.1
# 1  dc2b14d9ce3a0ce4050bb640190f2ca5  win8defender   1.1.15100.1
# 2  fd20c5f010e9c5f91ad1c6b3e0da68a0  win8defender   1.1.15200.1
# 3  38711eae85eb77a72ec5dfdf27eb2a76  win8defender   1.1.15200.1
# 4  32607c9a543a9214e2c7e45800ed4849  win8defender   1.1.15200.1
#
#          AppVersion SignatureVersion  IsBetaUser  RealTimeProtectionState  \
# 0   4.18.1807.18075     1.275.1003.0           0                      7.0
# 1   4.18.1807.18075     1.273.1465.0           0                      7.0
# 2   4.18.1807.18075     1.275.1546.0           0                      7.0
# 3  4.12.17007.18011     1.275.1141.0           0                      7.0
# 4    4.13.17134.228     1.275.1283.0           0                      7.0
#
#    IsPassiveModeEnabled  AntivirusConfigID  NumAntivirusProductsInstalled  \
# ...

# %%
df = df.reindex(sorted(df.columns), axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 76 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   AntivirusConfigID                   99924 non-null   float64
#  1   AppVersion                          100000 non-null  object
#  2   AutoSampleSubmissionEnabled         100000 non-null  int64
#  3   AutoUpdateOptionsName               100000 non-null  object
#  4   ChassisType                         99998 non-null   object
#  5   CityID                              99377 non-null   float64
#  6   CountryID                           100000 non-null  int64
#  7   DateAS                              100000 non-null  object
#  8   DateOS                              99976 non-null   object
#  9   DeviceFamily                        100000 non-null  object
#  10  EnableLUA                           99981 non-null   float64
# ...

# %% [markdown]
# ## How many unique versions of the operating system are present in the dataset?

# %%
# Assuming the column representing the OS version is 'OSBuild'
unique_os_versions = df['OSBuildNumber'].nunique()
print(f"Number of unique OS versions: {unique_os_versions}")
# Out:
# Number of unique OS versions: 24

# %% [markdown]
# ## What is the maximum value of the feature “NumAntivirusProductsInstalled”?

# %%
df['NumAntivirusProductsInstalled'].max()
# Out:
# 5.0

# %% [markdown]
# ## In how many systems owned by gamers was malware detected?

# %%
df[(df['IsGamer']==1.0)&(df['target']==1)].shape[0]
# Out:
# 16294

# %% [markdown]
# ## For observations where the feature “IsPassiveModeEnabled” equals “1,” what is the most frequent value of the feature “RealTimeProtectionState”?

# %%
f =df[df["IsPassiveModeEnabled"]==1]
df["RealTimeProtectionState"].mode()[0]
# Out:
# 7.0

# %% [markdown]
# ## How many systems have a screen resolution of 1366 x 768?

# %%
df[(df['PrimaryDisplayResolutionHorizontal'] == 1366) & (df['PrimaryDisplayResolutionVertical'] == 768)].shape[0]
# Out:
# 51435

# %% [markdown]
# ## What is the 50th percentile value of “TotalPhysicalRAMMB”?

# %%
df["TotalPhysicalRAMMB"].median()
# Out:
# 4096.0

# %% [markdown]
# ## Explain the Data using any Exploratory Data Analysis (EDA) you have used

# %%
print("Shape of the dataset:")
print(df.shape)  # (rows, columns)

# Summary statistics
print("\nSummary Statistics:")
print(df.describe())  # Descriptive stats for numeric columns

# Checking missing values
print("\nMissing Values per Column:")
print(df.isnull().sum())
# Out:
# Shape of the dataset:
# (100000, 76)
#
# Summary Statistics:
#        AntivirusConfigID  AutoSampleSubmissionEnabled         CityID  \
# count       99924.000000                     100000.0   99377.000000
# mean        47975.710440                          0.0   81029.938587
# std         13803.321533                          0.0   48944.027074
# min            39.000000                          0.0       7.000000
# 25%         49480.000000                          0.0   36694.000000
# 50%         53447.000000                          0.0   82373.000000
# 75%         53447.000000                          0.0  122835.000000
# max         70490.000000                          0.0  167957.000000
#
#            CountryID     EnableLUA  FirewallEnabled  FirmwareManufacturerID  \
# count  100000.000000  99981.000000     99834.000000            99624.000000
# mean      108.078790      0.996569         0.980067              401.987613
# ...
